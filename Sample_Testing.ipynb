# %%
import numpy as np
from keras.models import load_model

# %%
# Load the saved model
resnet_model = load_model('/content/drive/MyDrive/Classify Culinary items using Deep Learning/culinary_resnet50.h5')

# %%
# Define label meanings
label_meanings = {
    0: 'French fries',
    1: 'Fried rice',
    2: 'Nachos',
    3: 'Salad',
    4: 'Sphagetti'
}

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Model
import cv2
from tensorflow.keras.preprocessing import image

img_path = '/content/drive/MyDrive/Classify Culinary items using Deep Learning/sample test images/French-Fries.jpg'
img = image.load_img(img_path, target_size=(224, 224))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.
plt.imshow(img_tensor[0])
plt.show()
print(img_tensor.shape)

X = image.img_to_array(img)
X = np.expand_dims(X,axis = 0)
#images = np.vstack([X])
softmax_score = resnet_model.predict(X)
print("softmax score:")
print(softmax_score)
#print("Class: ")
val = softmax_score.argmax()
#print(val)

# Print label meaning
print("Class: ", label_meanings[val])
# Out:
# (1, 224, 224, 3)
# 1/1 [==============================] - 0s 486ms/step
# softmax score:
# [[9.7303557e-01 2.4923929e-03 1.3310317e-05 7.2993600e-04 2.3728747e-02]]
# Class:  French fries

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Model
import cv2
from tensorflow.keras.preprocessing import image

img_path = '/content/drive/MyDrive/Classify Culinary items using Deep Learning/sample test images/Spaghetti.jpg'
img = image.load_img(img_path, target_size=(224, 224))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.
plt.imshow(img_tensor[0])
plt.show()
print(img_tensor.shape)

X = image.img_to_array(img)
X = np.expand_dims(X,axis = 0)
#images = np.vstack([X])
softmax_score = resnet_model.predict(X)
print("softmax score:")
print(softmax_score)
#print("Class: ")
val = softmax_score.argmax()
#print(val)

# Print label meaning
print("Class: ", label_meanings[val])
# Out:
# (1, 224, 224, 3)
# 1/1 [==============================] - 0s 216ms/step
# softmax score:
# [[1.1346413e-06 7.1743678e-08 8.2124378e-09 6.1443153e-08 9.9999869e-01]]
# Class:  Sphagetti

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Model
import cv2
from tensorflow.keras.preprocessing import image

img_path = '/content/drive/MyDrive/Classify Culinary items using Deep Learning/sample test images/fried-rice.jpg'
img = image.load_img(img_path, target_size=(224, 224))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.
plt.imshow(img_tensor[0])
plt.show()
print(img_tensor.shape)

X = image.img_to_array(img)
X = np.expand_dims(X,axis = 0)
#images = np.vstack([X])
softmax_score = resnet_model.predict(X)
print("softmax score:")
print(softmax_score)
#print("Class: ")
val = softmax_score.argmax()
#print(val)

# Print label meaning
print("Class: ", label_meanings[val])
# Out:
# (1, 224, 224, 3)
# 1/1 [==============================] - 0s 211ms/step
# softmax score:
# [[4.7923102e-05 9.1536719e-01 8.3216287e-02 4.5569905e-04 9.1288390e-04]]
# Class:  Fried rice

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Model
import cv2
from tensorflow.keras.preprocessing import image

img_path = '/content/drive/MyDrive/Classify Culinary items using Deep Learning/sample test images/nachos.jpg'
img = image.load_img(img_path, target_size=(224, 224))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.
plt.imshow(img_tensor[0])
plt.show()
print(img_tensor.shape)

X = image.img_to_array(img)
X = np.expand_dims(X,axis = 0)
#images = np.vstack([X])
softmax_score = resnet_model.predict(X)
print("softmax score:")
print(softmax_score)
#print("Class: ")
val = softmax_score.argmax()
#print(val)

# Print label meaning
print("Class: ", label_meanings[val])
# Out:
# (1, 224, 224, 3)
# 1/1 [==============================] - 0s 219ms/step
# softmax score:
# [[8.3890924e-04 2.9914342e-02 7.4091971e-01 2.2817743e-01 1.4956301e-04]]
# Class:  Nachos

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Model
import cv2
from tensorflow.keras.preprocessing import image

img_path = '/content/drive/MyDrive/Classify Culinary items using Deep Learning/sample test images/salad.jpg'
img = image.load_img(img_path, target_size=(224, 224))
img_tensor = image.img_to_array(img)
img_tensor = np.expand_dims(img_tensor, axis=0)
img_tensor /= 255.
plt.imshow(img_tensor[0])
plt.show()
print(img_tensor.shape)

X = image.img_to_array(img)
X = np.expand_dims(X,axis = 0)
#images = np.vstack([X])
softmax_score = resnet_model.predict(X)
print("softmax score:")
print(softmax_score)
#print("Class: ")
val = softmax_score.argmax()
#print(val)

# Print label meaning
print("Class: ", label_meanings[val])
# Out:
# (1, 224, 224, 3)
# 1/1 [==============================] - 0s 197ms/step
# softmax score:
# [[4.6731465e-08 2.3290513e-05 6.7343033e-05 9.9990928e-01 1.0306661e-08]]
# Class:  Salad
